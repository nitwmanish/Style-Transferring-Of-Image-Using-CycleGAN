# %% [markdown]
# # Style Transferring Of Image Using Cycle GAN With summer2winter_yosemite Dataset

# %% [markdown]
# It's important to note that we are using a keras_contributer layer ,the InstanceNormalization layer. This layer is used in the original CycleGAN paper (https://arxiv.org/pdf/1703.10593.pdf) and it is an open source implementation.
#
# Instance Normalization (IN) is Batch Normalization (BN) per sample of data (IN is BN per image or per feature).
# * In style transfer, it's important to normalize the contrast per sample not per batch.
# * Instance normalization is equivalent to contrast normalization.
# * Meanwhile, Batch normalization breaks contrast normalization.
#
# We need to install keras-contrib, before using Instance Normalization.
# To install keras-contrib do following steps if you are using anaconda in windod 10.
#  * (1) Run Anaconda Prompt
#  * (2) Run below command if you are using different env other than default one.
#        activate myenv
#
#  * (3) Run Run below
#        pip3 install git+https://www.github.com/keras-team/keras-contrib.git
#
#
# Note that we are not using graphviz, but I got this on solution while doing some randome search and it work for me on window 10 so i am documentiing this just for future reference.
# To install graphviz, please do the following steps.
#
#  * (1) Run Anaconda Prompt
#  * (2) Run below command if you are using different env other than default one.
#        activate myenv
#
#  * (3) Run Run below
#        conda install python-graphviz
#
# "conda install python-graphviz" command should be run instead of "pip install graphviz" command.

# %% [markdown]
# #### I run this Jupyternote book on https://colab.research.google.com. Inorder to run jupyter notebook on colab, I was required to upload my dataset in my google drive and mount it so that colab can access dataset  and also install required module. So these steps are also there in this notebook.

# %% [markdown]
# Install and Imports the required module.

# %%
# !pip3 install git+https://www.github.com/keras-team/keras-contrib.git
from google.colab import drive
drive.mount('/content/gdrive')

import os
import sys
import random
import numpy as np
from PIL import Image
from random import randint
from copy import deepcopy
import matplotlib.pyplot as plt


import keras.backend as K
from keras import initializers
from keras.utils import plot_model
from keras.layers.core import Activation
from keras.models import Sequential, Model
from keras.layers.convolutional import Convolution2D
from keras.optimizers import Adam, SGD,Nadam, Adamax
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, MaxPooling2D,Deconvolution2D
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, BatchNormalization, Lambda, Concatenate
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-z1rfqkp5
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-z1rfqkp5
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.9)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.16.3)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.2.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vy4xr22v/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Using TensorFlow backend.

# %% [markdown]
# #### CycleGAN datasets can be downloaded from below link.
# https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/

# %% [markdown]
# In CycleGAN we will downsample for a few blocks then upsample. We will also use a new layer called InstanceNormalization that was used by authors to enforce better training for style transfer.
# * The first part of the model involves 2D convolutions with this InstanceNormalization layer.
# * The upsample blocks are similar to the downsample but bring us back up to the original resolution of our images.
# * The last part of the generator model method is the output layer and the structure of this model.

# %%
class Generator(object):
    def __init__(self, width = 28, height= 28, channels = 1):
        
        self.W = width
        self.H = height
        self.C = channels
        self.SHAPE = (width,height,channels)

        self.Generator = self.model()
        self.OPTIMIZER = Adam(lr=2e-4, beta_1=0.5,decay=1e-5)
        self.Generator.compile(loss='binary_crossentropy', optimizer=self.OPTIMIZER,metrics=['accuracy'])

        # self.save_model()
        self.summary()

    def model(self):
        input_layer = Input(shape=self.SHAPE)
        
        down_1 = Convolution2D(64  , kernel_size=4, strides=2, padding='same',activation=LeakyReLU(alpha=0.2))(input_layer)
        norm_1 = InstanceNormalization()(down_1)

        down_2 = Convolution2D(64*2, kernel_size=4, strides=2, padding='same',activation=LeakyReLU(alpha=0.2))(norm_1)
        norm_2 = InstanceNormalization()(down_2)

        down_3 = Convolution2D(64*4, kernel_size=4, strides=2, padding='same',activation=LeakyReLU(alpha=0.2))(norm_2)
        norm_3 = InstanceNormalization()(down_3)

        down_4 = Convolution2D(64*8, kernel_size=4, strides=2, padding='same',activation=LeakyReLU(alpha=0.2))(norm_3)
        norm_4 = InstanceNormalization()(down_4)


        upsample_1 = UpSampling2D()(norm_4)
        up_conv_1 = Convolution2D(64*4, kernel_size=4, strides=1, padding='same',activation='relu')(upsample_1)
        norm_up_1 = InstanceNormalization()(up_conv_1)
        add_skip_1 = Concatenate()([norm_up_1,norm_3])

        upsample_2 = UpSampling2D()(add_skip_1)
        up_conv_2 = Convolution2D(64*2, kernel_size=4, strides=1, padding='same',activation='relu')(upsample_2)
        norm_up_2 = InstanceNormalization()(up_conv_2)
        add_skip_2 = Concatenate()([norm_up_2,norm_2])

        upsample_3 = UpSampling2D()(add_skip_2)
        up_conv_3 = Convolution2D(64, kernel_size=4, strides=1, padding='same',activation='relu')(upsample_3)
        norm_up_3 = InstanceNormalization()(up_conv_3)
        add_skip_3 = Concatenate()([norm_up_3,norm_1])

        last_upsample = UpSampling2D()(add_skip_3)
        output_layer = Convolution2D(3, kernel_size=4, strides=1, padding='same',activation='tanh')(last_upsample)
        
        return Model(input_layer,output_layer)

    def summary(self):
        return self.Generator.summary()

    def save_model(self):
        plot_model(self.Generator.model, to_file='/content/gdrive/My Drive/ColabNotebooks/data/Generator_Model.png')

# %% [markdown]
# * Discriminator has a few 2D convolutional layers until we get to our output layer.
# * The final few layers will bring us back to our output variable and appropriately flatten it.

# %%
class Discriminator(object):
    def __init__(self, width = 28, height= 28, channels = 1):
        self.W = width
        self.H = height
        self.C = channels
        self.CAPACITY = width*height*channels
        self.SHAPE = (width,height,channels)
        
        self.Discriminator = self.model()
        self.OPTIMIZER = Adam(lr=2e-4, beta_1=0.5,decay=1e-5)
        self.Discriminator.compile(loss='mse', optimizer=self.OPTIMIZER, metrics=['accuracy'] )

        # self.save_model()
        self.summary()

    def model(self):
        input_layer = Input(self.SHAPE)

        up_layer_1 = Convolution2D(64, kernel_size=4, strides=2, padding='same',activation=LeakyReLU(alpha=0.2))(input_layer)

        up_layer_2 = Convolution2D(64*2, kernel_size=4, strides=2, padding='same',activation=LeakyReLU(alpha=0.2))(up_layer_1)
        norm_layer_1 = InstanceNormalization()(up_layer_2)

        up_layer_3 = Convolution2D(64*4, kernel_size=4, strides=2, padding='same',activation=LeakyReLU(alpha=0.2))(norm_layer_1)
        norm_layer_2 = InstanceNormalization()(up_layer_3)

        up_layer_4 = Convolution2D(64*8, kernel_size=4, strides=2, padding='same',activation=LeakyReLU(alpha=0.2))(norm_layer_2)
        norm_layer_3 =InstanceNormalization()(up_layer_4)

        output_layer = Convolution2D(1, kernel_size=4, strides=1, padding='same')(norm_layer_3)
        output_layer_1 = Flatten()(output_layer)
        output_layer_2 = Dense(1, activation='sigmoid')(output_layer_1)
        
        return Model(input_layer,output_layer_2)

    def summary(self):
        return self.Discriminator.summary()

    def save_model(self):
        plot_model(self.Discriminator.model, to_file='./content/gdrive/My Drive/ColabNotebooks/data/Discriminator_Model.png')

# %% [markdown]
# * The GAN model will have six models in adversarial training mode.
# * lambda _cycle and lambda_id refer to the values of the loss functions for the X to Y generation and X to Y to X reconstruction generation, respectively. The lambda_id parameter should be 10% (according to the paper) of the lambda_cycle variable.

# %%
class GAN(object):
    def __init__(self, model_inputs=[],model_outputs=[],lambda_cycle=10.0,lambda_id=1.0):
        self.OPTIMIZER = SGD(lr=2e-4,nesterov=True)
        # self.inputs are represented by an array of two Keras input classes instantiated in the training class and passed to the GAN class.
        self.inputs = model_inputs
        # Create a model with the input and output passed from the training class.
        self.outputs = model_outputs
        self.gan_model = Model(self.inputs,self.outputs)
        self.OPTIMIZER = Adam(lr=2e-4, beta_1=0.5)
        # The output array is six models, four generators, and two discriminators in an adversarial setup.
        self.gan_model.compile(loss=['mse', 'mse',
                                    'mae', 'mae',
                                    'mae', 'mae'],
                            loss_weights=[  1, 1,
                                            lambda_cycle, lambda_cycle,
                                            lambda_id, lambda_id ],
                            optimizer=self.OPTIMIZER)
        # self.save_model()
        self.summary()

    def model(self):
        model = Model()
        return model

    def summary(self):
        return self.gan_model.summary()

    def save_model(self):
        plot_model(self.gan_model.model, to_file='/content/gdrive/My Drive/ColabNotebooks/data/GAN_Model.png')

# %% [markdown]
# Trainer class. We now have two separate folders for both a training and test setup. We will train a model on one dataset and demonstrate the results of the generator on the test dataset. This makes sure that we aren't overfitting to the relationship we are learning between the train_A and train_B datasets

# %%
class Trainer:
    def __init__(self, height = 64, width = 64, epochs = 50000, batch = 32, checkpoint = 50, train_data_path_A = '',train_data_path_B = '',test_data_path_A='',test_data_path_B='',lambda_cycle=10.0,lambda_id=1.0):
        self.EPOCHS = epochs
        self.BATCH = batch
        self.RESIZE_HEIGHT = height
        self.RESIZE_WIDTH = width
        self.CHECKPOINT = checkpoint
        # Load all of the data into its respective class variables
        self.X_train_A, self.H_A, self.W_A, self.C_A = self.load_data(train_data_path_A)
        self.X_train_B, self.H_B, self.W_B, self.C_B  = self.load_data(train_data_path_B)
        self.X_test_A, self.H_A_test, self.W_A_test, self.C_A_test = self.load_data(test_data_path_A)
        self.X_test_B, self.H_B_test, self.W_B_test, self.C_B_test  = self.load_data(test_data_path_B)
         
        '''We need the generators that go from A to B and from B to A. 
        The instantiation of these models is direct.'''
        self.generator_A_to_B = Generator(height=self.H_A, width=self.W_A, channels=self.C_A)
        self.generator_B_to_A = Generator(height=self.H_B, width=self.W_B, channels=self.C_B)
        
        #  following lines to instantiation in the class definition for training
        '''We need to make sure we have the original A and B images stored as the Input class from Keras. 
        Variables orig_A and orig_B are the input values shared among the next three components.''' 
        self.orig_A = Input(shape=(self.W_A, self.H_A, self.C_A))
        self.orig_B = Input(shape=(self.W_B, self.H_B, self.C_B))
        '''fake_A and fake_B are the generators that take us from one style to the other and produce 
        an image with the translated style. Hence, this is why we say they are fake.'''
        self.fake_B = self.generator_A_to_B.Generator(self.orig_A)
        self.fake_A = self.generator_B_to_A.Generator(self.orig_B)
        '''reconstructed_A and reconstructed_B take the fake A and B images and retranslate 
        them into the original image style.'''
        self.reconstructed_A = self.generator_B_to_A.Generator(self.fake_B)
        self.reconstructed_B = self.generator_A_to_B.Generator(self.fake_A)
        '''id_A and id_B are identity functions because they take in the original image and translate 
        back into the same style. Ideally, these functions would not apply any style changes to these images'''
        self.id_A = self.generator_B_to_A.Generator(self.orig_A)
        self.id_B = self.generator_A_to_B.Generator(self.orig_B)

        '''We need our discriminators that evaluate both A and B images. 
        We also need a validity discriminator that checks the fake_A and fake_B generators'''
        self.discriminator_A = Discriminator(height=self.H_A, width=self.W_A, channels=self.C_A)
        self.discriminator_B = Discriminator(height=self.H_B, width=self.W_B, channels=self.C_B)
        self.discriminator_A.trainable = False
        self.discriminator_B.trainable = False
        self.valid_A = self.discriminator_A.Discriminator(self.fake_A)
        self.valid_B = self.discriminator_B.Discriminator(self.fake_B)

        ''' we are able to simply pass all of the models to the GAN class 
        and it will construct our adversarial model'''
        model_inputs  = [self.orig_A,self.orig_B]
        model_outputs = [self.valid_A, self.valid_B,self.reconstructed_A,self.reconstructed_B,self.id_A, self.id_B]
        self.gan = GAN(model_inputs=model_inputs,model_outputs=model_outputs,lambda_cycle=lambda_cycle,lambda_id=lambda_id)
        
    # The load_data function expects a string that represents the path to the folder and it'll read every image with a certain file ending within that folder.
    def load_data(self,data_path,amount_of_data = 1.0):
        listOFFiles = self.grabListOfFiles(data_path,extension="jpg")
        X_train = np.array(self.grabArrayOfImages(listOFFiles))
        height, width, channels = np.shape(X_train[0])
        X_train = X_train[:int(amount_of_data*float(len(X_train)))]
        X_train = (X_train.astype(np.float32) - 127.5)/127.5
        X_train = np.expand_dims(X_train, axis=3)
        return X_train, height, width, channels

    def grabListOfFiles(self,startingDirectory,extension=".webp"):
        listOfFiles = []
        for file in os.listdir(startingDirectory):
            if file.endswith(extension):
                listOfFiles.append(os.path.join(startingDirectory, file))
        return listOfFiles

    def grabArrayOfImages(self,listOfFiles,gray=False):
        imageArr = []
        for f in listOfFiles:
            if gray:
                im = Image.open(f).convert("L")
            else:
                im = Image.open(f).convert("RGB")
            im = im.resize((self.RESIZE_WIDTH,self.RESIZE_HEIGHT))
            imData = np.asarray(im)
            imageArr.append(imData)
        return imageArr

    '''we need to collect our data for our batch generator differently and 
    we need to train each one of the discriminators we just developed (four in total)'''
    def train(self):
        for e in range(self.EPOCHS):
            b = 0
            X_train_A_temp = deepcopy(self.X_train_A)
            X_train_B_temp = deepcopy(self.X_train_B)
            '''Because the batch represents a single image, it isn't strictly required that each domain 
            contain the same number of images. Now, this means that our while statement needs to take 
            into account that there is one folder smaller than the other. The epoch will end when 
            there are no more images in the smaller array of images between A and B.'''
            while min(len(X_train_A_temp),len(X_train_B_temp))>self.BATCH:
                # Keep track of Batches
                b=b+1

                # Train Discriminator
                # Grab Real Images for this training batch
                '''we need to have an A and B version of our batches'''
                count_real_images = int(self.BATCH)
                starting_indexs = randint(0, (min(len(X_train_A_temp),len(X_train_B_temp))-count_real_images))
                real_images_raw_A = X_train_A_temp[ starting_indexs : (starting_indexs + count_real_images) ]
                real_images_raw_B = X_train_B_temp[ starting_indexs : (starting_indexs + count_real_images) ]

                # Delete the images used until we have none left
                X_train_A_temp = np.delete(X_train_A_temp,range(starting_indexs,(starting_indexs + count_real_images)),0)
                X_train_B_temp = np.delete(X_train_B_temp,range(starting_indexs,(starting_indexs + count_real_images)),0)
                batch_A = real_images_raw_A.reshape( count_real_images, self.W_A, self.H_A, self.C_A )
                batch_B = real_images_raw_B.reshape( count_real_images, self.W_B, self.H_B, self.C_B )

                self.discriminator_A.Discriminator.trainable = True
                self.discriminator_B.Discriminator.trainable = True
                x_batch_A = batch_A
                x_batch_B = batch_B
                y_batch_A = np.ones([count_real_images,1])
                y_batch_B = np.ones([count_real_images,1])
                # Now, train the discriminator with this batch of reals
                discriminator_loss_A_real = self.discriminator_A.Discriminator.train_on_batch(x_batch_A,y_batch_A)[0]
                discriminator_loss_B_real = self.discriminator_B.Discriminator.train_on_batch(x_batch_B,y_batch_B)[0]

                x_batch_B = self.generator_A_to_B.Generator.predict(batch_A)
                x_batch_A = self.generator_B_to_A.Generator.predict(batch_B)
                y_batch_A = np.zeros([self.BATCH,1])
                y_batch_B = np.zeros([self.BATCH,1])
                # Now, train the discriminator with this batch of fakes
                discriminator_loss_A_fake = self.discriminator_A.Discriminator.train_on_batch(x_batch_A,y_batch_A)[0]
                discriminator_loss_B_fake = self.discriminator_B.Discriminator.train_on_batch(x_batch_B,y_batch_B)[0]    

                self.discriminator_A.Discriminator.trainable = False
                self.discriminator_B.Discriminator.trainable = False

                discriminator_loss_A = 0.5*(discriminator_loss_A_real + discriminator_loss_A_fake)
                discriminator_loss_B = 0.5*(discriminator_loss_B_real + discriminator_loss_B_fake)
            
                # In practice, flipping the label when training the generator improves convergence
                '''we introduce label noise into the training process with the development of the 
                batches for training the individual discriminators'''
                if self.flipCoin(chance=0.9):
                    y_generated_labels = np.ones([self.BATCH,1])
                else:
                    y_generated_labels = np.zeros([self.BATCH,1])
                generator_loss = self.gan.gan_model.train_on_batch([x_batch_A, x_batch_B],
                                                        [y_generated_labels, y_generated_labels,
                                                        x_batch_A, x_batch_B,
                                                        x_batch_A, x_batch_B])    

                print ('Epoch: '+str(int(e))+' Batch: '+str(int(b))+', [Discriminator_A :: Loss: '+str(discriminator_loss_A)+'], [ Generator :: Loss: '+str(generator_loss)+']')
                print ('Epoch: '+str(int(e))+' Batch: '+str(int(b))+', [Discriminator_B :: Loss: '+str(discriminator_loss_B)+'], [ Generator :: Loss: '+str(generator_loss)+']')
                if b % self.CHECKPOINT == 0 :
                    label = str(e)+'_'+str(b)
                    self.plot_checkpoint(label)

            print ('Epoch: '+str(int(e))+', [Discriminator_A :: Loss: '+str(discriminator_loss_A)+'], [ Generator :: Loss: '+str(generator_loss)+']')
            print ('Epoch: '+str(int(e))+', [Discriminator_A :: Loss: '+str(discriminator_loss_B)+'], [ Generator :: Loss: '+str(generator_loss)+']')
                        
            #if e % self.CHECKPOINT == 0 :
                #self.plot_checkpoint(e)
        return
 
    def flipCoin(self,chance=0.5):
        return np.random.binomial(1, chance)

    def plot_checkpoint(self,b):
        orig_filename = "/content/gdrive/My Drive/ColabNotebooks/data/batch_check_"+str(b)+"_original.png"

        image_A = self.X_test_A[5]
        image_A = np.reshape(image_A, [self.W_A_test,self.H_A_test,self.C_A_test])
        print("Image_A shape: " +str(np.shape(image_A)))
        fake_B = self.generator_A_to_B.Generator.predict(image_A.reshape(1, self.W_A, self.H_A, self.C_A ))
        fake_B = np.reshape(fake_B, [self.W_A_test,self.H_A_test,self.C_A_test])
        print("fake_B shape: " +str(np.shape(fake_B)))
        reconstructed_A = self.generator_B_to_A.Generator.predict(fake_B.reshape(1, self.W_A, self.H_A, self.C_A ))
        reconstructed_A = np.reshape(reconstructed_A, [self.W_A_test,self.H_A_test,self.C_A_test])
        print("reconstructed_A shape: " +str(np.shape(reconstructed_A)))
        # from IPython import embed; embed()

        checkpoint_images = np.array([image_A, fake_B, reconstructed_A])

        # Rescale images 0 - 1
        checkpoint_images = 0.5 * checkpoint_images + 0.5

        titles = ['Original', 'Translated', 'Reconstructed']
        fig, axes = plt.subplots(1, 3)
        for i in range(3):
            image = checkpoint_images[i]
            image = np.reshape(image, [self.H_A_test,self.W_A_test,self.C_A_test])
            axes[i].imshow(image)
            axes[i].set_title(titles[i])
            axes[i].axis('off')
        fig.savefig("/content/gdrive/My Drive/ColabNotebooks/data/batch_check_"+str(b)+".png")
        plt.close('all')
        return

# %% [markdown]
# Let's start training. Here I run for the 5 EPOCHS, for the better result the value of EPOCHS need to be more like around 100.

# %%
# Command Line Argument Method
HEIGHT  = 64
WIDTH   = 64
CHANNEL = 3
EPOCHS = 5
#EPOCHS = 2
# our batch in this base is only a single image.
BATCH = 1
CHECKPOINT = 200
from google.colab import drive

TRAIN_PATH_A = "/content/gdrive/My Drive/ColabNotebooks/data/summer2winter_yosemite/trainA/"
TRAIN_PATH_B = "/content/gdrive/My Drive/ColabNotebooks/data/summer2winter_yosemite/trainA/"
TEST_PATH_A = "/content/gdrive/My Drive/ColabNotebooks/data/summer2winter_yosemite/trainA/"
TEST_PATH_B = "/content/gdrive/My Drive/ColabNotebooks/data/summer2winter_yosemite/trainA/"

trainer = Trainer(height=HEIGHT,width=WIDTH,epochs =EPOCHS,\
                 batch=BATCH,\
                 checkpoint=CHECKPOINT,\
                 train_data_path_A=TRAIN_PATH_A,\
                 train_data_path_B=TRAIN_PATH_B,\
                 test_data_path_A=TEST_PATH_A,\
                 test_data_path_B=TEST_PATH_B,\
                 lambda_cycle=10.0,\
                 lambda_id=1.0)
trainer.train()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /usr/local/lib/python3.6/dist-packages/keras/activations.py:211: UserWarning: Do not pass a layer instance (such as LeakyReLU) as the activation argument of another layer. Instead, advanced activation layers should be used just like any other layer in a model.
#   identifier=identifier.__class__.__name__))
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   3136        input_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_1 (Insta (None, 32, 32, 64)   2           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  131200      instance_normalization_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_2 (Insta (None, 16, 16, 128)  2           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 256)    524544      instance_normalization_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_3 (Insta (None, 8, 8, 256)    2           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 512)    2097664     instance_normalization_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_4 (Insta (None, 4, 4, 512)    2           conv2d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 512)    0           instance_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 256)    2097408     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_5 (Insta (None, 8, 8, 256)    2           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 512)    0           instance_normalization_5[0][0]
#                                                                  instance_normalization_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 512)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  1048704     up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_6 (Insta (None, 16, 16, 128)  2           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 256)  0           instance_normalization_6[0][0]
#                                                                  instance_normalization_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 256)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   262208      up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_7 (Insta (None, 32, 32, 64)   2           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 128)  0           instance_normalization_7[0][0]
#                                                                  instance_normalization_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 128)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 3)    6147        up_sampling2d_4[0][0]
# ==================================================================================================
# Total params: 6,171,025
# Trainable params: 6,171,025
# Non-trainable params: 0
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   3136        input_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_8 (Insta (None, 32, 32, 64)   2           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  131200      instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# instance_normalization_9 (Insta (None, 16, 16, 128)  2           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 256)    524544      instance_normalization_9[0][0]
# __________________________________________________________________________________________________
# instance_normalization_10 (Inst (None, 8, 8, 256)    2           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 512)    2097664     instance_normalization_10[0][0]
# __________________________________________________________________________________________________
# instance_normalization_11 (Inst (None, 4, 4, 512)    2           conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 8, 8, 512)    0           instance_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    2097408     up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# instance_normalization_12 (Inst (None, 8, 8, 256)    2           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 512)    0           instance_normalization_12[0][0]
#                                                                  instance_normalization_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 16, 16, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  1048704     up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# instance_normalization_13 (Inst (None, 16, 16, 128)  2           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 256)  0           instance_normalization_13[0][0]
#                                                                  instance_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 32, 32, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 64)   262208      up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# instance_normalization_14 (Inst (None, 32, 32, 64)   2           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 128)  0           instance_normalization_14[0][0]
#                                                                  instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 64, 64, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 3)    6147        up_sampling2d_8[0][0]
# ==================================================================================================
# Total params: 6,171,025
# Trainable params: 6,171,025
# Non-trainable params: 0
# __________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 32, 64)        3136
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 128)       131200
# _________________________________________________________________
# instance_normalization_15 (I (None, 16, 16, 128)       2
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 8, 256)         524544
# _________________________________________________________________
# instance_normalization_16 (I (None, 8, 8, 256)         2
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 4, 4, 512)         2097664
# _________________________________________________________________
# instance_normalization_17 (I (None, 4, 4, 512)         2
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 4, 4, 1)           8193
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,764,760
# Trainable params: 2,764,760
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 32, 32, 64)        3136
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 16, 16, 128)       131200
# _________________________________________________________________
# instance_normalization_18 (I (None, 16, 16, 128)       2
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 8, 8, 256)         524544
# _________________________________________________________________
# instance_normalization_19 (I (None, 8, 8, 256)         2
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 4, 4, 512)         2097664
# _________________________________________________________________
# instance_normalization_20 (I (None, 4, 4, 512)         2
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 4, 4, 1)           8193
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,764,760
# Trainable params: 2,764,760
# Non-trainable params: 0
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 64, 64, 3)    6171025     input_4[0][0]
#                                                                  model_1[1][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 64, 64, 3)    6171025     input_3[0][0]
#                                                                  model_2[1][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 1)            2764760     model_2[1][0]
# __________________________________________________________________________________________________
# model_4 (Model)                 (None, 1)            2764760     model_1[1][0]
# ==================================================================================================
# Total params: 17,871,570
# Trainable params: 17,871,570
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch: 0 Batch: 1, [Discriminator_A :: Loss: 0.09788170456886292], [ Generator :: Loss: [17.179867, 0.5120663, 1.3129215e-05, 0.8190216, 0.6724811, 0.8467978, 0.9059619]]
# Epoch: 0 Batch: 1, [Discriminator_B :: Loss: 0.0909140333533287], [ Generator :: Loss: [17.179867, 0.5120663, 1.3129215e-05, 0.8190216, 0.6724811, 0.8467978, 0.9059619]]
# Epoch: 0 Batch: 2, [Discriminator_A :: Loss: 6.822723207733361e-06], [ Generator :: Loss: [14.231139, 4.7356966e-08, 0.55480725, 0.9202812, 0.2507617, 0.93450963, 1.0313929]]
# Epoch: 0 Batch: 2, [Discriminator_B :: Loss: 4.783581530887204e-09], [ Generator :: Loss: [14.231139, 4.7356966e-08, 0.55480725, 0.9202812, 0.2507617, 0.93450963, 1.0313929]]
# Epoch: 0 Batch: 3, [Discriminator_A :: Loss: 0.0060838148929178715], [ Generator :: Loss: [9.25607, 1.6575541e-10, 1.4210855e-14, 0.46548218, 0.20372733, 1.1464357, 1.4175389]]
# Epoch: 0 Batch: 3, [Discriminator_B :: Loss: 8.855048916345254e-10], [ Generator :: Loss: [9.25607, 1.6575541e-10, 1.4210855e-14, 0.46548218, 0.20372733, 1.1464357, 1.4175389]]
# Epoch: 0 Batch: 4, [Discriminator_A :: Loss: 4.404177616379457e-06], [ Generator :: Loss: [9.173688, 8.798138e-06, 5.111134e-05, 0.32528192, 0.3409459, 1.3289696, 1.1823802]]
# Epoch: 0 Batch: 4, [Discriminator_B :: Loss: 0.4999846816062927], [ Generator :: Loss: [9.173688, 8.798138e-06, 5.111134e-05, 0.32528192, 0.3409459, 1.3289696, 1.1823802]]
# Epoch: 0 Batch: 5, [Discriminator_A :: Loss: 6.605576885476694e-08], [ Generator :: Loss: [8.236341, 1.0436594e-09, 0.0, 0.32041764, 0.23854402, 1.181493, 1.4652314]]
# Epoch: 0 Batch: 5, [Discriminator_B :: Loss: 8.110054068311001e-07], [ Generator :: Loss: [8.236341, 1.0436594e-09, 0.0, 0.32041764, 0.23854402, 1.181493, 1.4652314]]
# Epoch: 0 Batch: 6, [Discriminator_A :: Loss: 2.4143411714305785e-09], [ Generator :: Loss: [9.789079, 6.8780537e-12, 1.4210855e-14, 0.3142494, 0.37801605, 1.2505465, 1.6158779]]
# Epoch: 0 Batch: 6, [Discriminator_B :: Loss: 4.090052949101697e-12], [ Generator :: Loss: [9.789079, 6.8780537e-12, 1.4210855e-14, 0.3142494, 0.37801605, 1.2505465, 1.6158779]]
# Epoch: 0 Batch: 7, [Discriminator_A :: Loss: 1.741931598964186e-09], [ Generator :: Loss: [5.7916913, 1.114131e-09, 0.0, 0.16194442, 0.120809555, 1.250043, 1.7141086]]
# Epoch: 0 Batch: 7, [Discriminator_B :: Loss: 9.739130617421321e-14], [ Generator :: Loss: [5.7916913, 1.114131e-09, 0.0, 0.16194442, 0.120809555, 1.250043, 1.7141086]]
# Epoch: 0 Batch: 8, [Discriminator_A :: Loss: 0.2097335308790207], [ Generator :: Loss: [7.2952504, 0.0, 2.2561153e-10, 0.26615542, 0.18489555, 1.1316081, 1.6531329]]
# Epoch: 0 Batch: 8, [Discriminator_B :: Loss: 0.3429422676563263], [ Generator :: Loss: [7.2952504, 0.0, 2.2561153e-10, 0.26615542, 0.18489555, 1.1316081, 1.6531329]]
# Epoch: 0 Batch: 9, [Discriminator_A :: Loss: 0.0005026026046834886], [ Generator :: Loss: [7.5968294, 0.0012832053, 0.9953956, 0.23057139, 0.14602874, 1.1344335, 1.6997154]]
# Epoch: 0 Batch: 9, [Discriminator_B :: Loss: 2.767817704807385e-06], [ Generator :: Loss: [7.5968294, 0.0012832053, 0.9953956, 0.23057139, 0.14602874, 1.1344335, 1.6997154]]
# Epoch: 0 Batch: 10, [Discriminator_A :: Loss: 0.041789911687374115], [ Generator :: Loss: [4.9481096, 2.4686017e-08, 0.0, 0.10809732, 0.10652395, 1.0661814, 1.7357156]]
# Epoch: 0 Batch: 10, [Discriminator_B :: Loss: 0.016564534977078438], [ Generator :: Loss: [4.9481096, 2.4686017e-08, 0.0, 0.10809732, 0.10652395, 1.0661814, 1.7357156]]
# Epoch: 0 Batch: 11, [Discriminator_A :: Loss: 8.026176099947186e-16], [ Generator :: Loss: [5.2893705, 0.0, 0.0, 0.1430957, 0.119026214, 0.9797596, 1.6883917]]
# Epoch: 0 Batch: 11, [Discriminator_B :: Loss: 2.731326276261825e-11], [ Generator :: Loss: [5.2893705, 0.0, 0.0, 0.1430957, 0.119026214, 0.9797596, 1.6883917]]
# Epoch: 0 Batch: 12, [Discriminator_A :: Loss: 8.164412201860927e-11], [ Generator :: Loss: [5.703847, 0.0, 0.0, 0.17907774, 0.12749623, 1.0345786, 1.6035287]]
# Epoch: 0 Batch: 12, [Discriminator_B :: Loss: 1.4239203114604446e-25], [ Generator :: Loss: [5.703847, 0.0, 0.0, 0.17907774, 0.12749623, 1.0345786, 1.6035287]]
# Epoch: 0 Batch: 13, [Discriminator_A :: Loss: 9.763412123220405e-08], [ Generator :: Loss: [5.2097664, 1.2789769e-13, 3.5527137e-13, 0.13457532, 0.10233839, 1.1041611, 1.7364681]]
# Epoch: 0 Batch: 13, [Discriminator_B :: Loss: 6.823628456897072e-19], [ Generator :: Loss: [5.2097664, 1.2789769e-13, 3.5527137e-13, 0.13457532, 0.10233839, 1.1041611, 1.7364681]]
# Epoch: 0 Batch: 14, [Discriminator_A :: Loss: 6.781317993037259e-14], [ Generator :: Loss: [6.3035913, 0.0, 2.5307259e-09, 0.24922025, 0.1084177, 0.9550692, 1.7721424]]
# Epoch: 0 Batch: 14, [Discriminator_B :: Loss: 3.3445421987465807e-09], [ Generator :: Loss: [6.3035913, 0.0, 2.5307259e-09, 0.24922025, 0.1084177, 0.9550692, 1.7721424]]
# Epoch: 0 Batch: 15, [Discriminator_A :: Loss: 4.2554740502964705e-05], [ Generator :: Loss: [4.9416633, 4.3894577e-08, 0.0, 0.109561265, 0.12313047, 0.89135265, 1.7233934]]
# Epoch: 0 Batch: 15, [Discriminator_B :: Loss: 0.2774032652378082], [ Generator :: Loss: [4.9416633, 4.3894577e-08, 0.0, 0.109561265, 0.12313047, 0.89135265, 1.7233934]]
# Epoch: 0 Batch: 16, [Discriminator_A :: Loss: 8.81970144652784e-17], [ Generator :: Loss: [6.097682, 0.0, 0.0, 0.17631382, 0.1850847, 0.8605082, 1.6231891]]
# Epoch: 0 Batch: 16, [Discriminator_B :: Loss: 3.2122880541900595e-22], [ Generator :: Loss: [6.097682, 0.0, 0.0, 0.17631382, 0.1850847, 0.8605082, 1.6231891]]
# Epoch: 0 Batch: 17, [Discriminator_A :: Loss: 0.4936528503894806], [ Generator :: Loss: [9.383929, 0.9982652, 0.9952316, 0.27546334, 0.23338073, 0.97542053, 1.3265703]]
# Epoch: 0 Batch: 17, [Discriminator_B :: Loss: 0.005843358114361763], [ Generator :: Loss: [9.383929, 0.9982652, 0.9952316, 0.27546334, 0.23338073, 0.97542053, 1.3265703]]
# Epoch: 0 Batch: 18, [Discriminator_A :: Loss: 1.092552629855352e-13], [ Generator :: Loss: [5.6800323, 0.0, 0.0, 0.1798259, 0.18609342, 0.73095524, 1.2898835]]
# Epoch: 0 Batch: 18, [Discriminator_B :: Loss: 1.358340580833541e-18], [ Generator :: Loss: [5.6800323, 0.0, 0.0, 0.1798259, 0.18609342, 0.73095524, 1.2898835]]
# Epoch: 0 Batch: 19, [Discriminator_A :: Loss: 0.26617103815078735], [ Generator :: Loss: [5.246625, 0.0, 0.0, 0.12459633, 0.17603566, 0.9451292, 1.295176]]
# Epoch: 0 Batch: 19, [Discriminator_B :: Loss: 0.7555840015411377], [ Generator :: Loss: [5.246625, 0.0, 0.0, 0.12459633, 0.17603566, 0.9451292, 1.295176]]
# Epoch: 0 Batch: 20, [Discriminator_A :: Loss: 0.025286618620157242], [ Generator :: Loss: [7.927458, 0.9999502, 0.99999666, 0.1845485, 0.1447002, 1.0712126, 1.5638114]]
# Epoch: 0 Batch: 20, [Discriminator_B :: Loss: 4.623732630494939e-16], [ Generator :: Loss: [7.927458, 0.9999502, 0.99999666, 0.1845485, 0.1447002, 1.0712126, 1.5638114]]
# Epoch: 0 Batch: 21, [Discriminator_A :: Loss: 0.4975352883338928], [ Generator :: Loss: [8.153993, 1.3096724e-10, 6.558833e-05, 0.3318068, 0.25441062, 0.8351722, 1.4565809]]
# Epoch: 0 Batch: 21, [Discriminator_B :: Loss: 0.0008708352106623352], [ Generator :: Loss: [8.153993, 1.3096724e-10, 6.558833e-05, 0.3318068, 0.25441062, 0.8351722, 1.4565809]]
# Epoch: 0 Batch: 22, [Discriminator_A :: Loss: 7.828865888903636e-10], [ Generator :: Loss: [6.654739, 8.8689944e-11, 0.0, 0.2549855, 0.16780365, 0.7757101, 1.6511368]]
# Epoch: 0 Batch: 22, [Discriminator_B :: Loss: 7.039425273804466e-20], [ Generator :: Loss: [6.654739, 8.8689944e-11, 0.0, 0.2549855, 0.16780365, 0.7757101, 1.6511368]]
# Epoch: 0 Batch: 23, [Discriminator_A :: Loss: 0.0001100356166716665], [ Generator :: Loss: [7.243378, 5.1159077e-13, 0.0, 0.3040642, 0.22176802, 0.52470434, 1.4603509]]
# Epoch: 0 Batch: 23, [Discriminator_B :: Loss: 2.4039392698682605e-10], [ Generator :: Loss: [7.243378, 5.1159077e-13, 0.0, 0.3040642, 0.22176802, 0.52470434, 1.4603509]]
# Epoch: 0 Batch: 24, [Discriminator_A :: Loss: 1.9029916531465574e-15], [ Generator :: Loss: [8.182304, 7.845941e-06, 1.4210855e-14, 0.27238852, 0.3056773, 0.8027948, 1.5988436]]
# Epoch: 0 Batch: 24, [Discriminator_B :: Loss: 2.949648175449432e-13], [ Generator :: Loss: [8.182304, 7.845941e-06, 1.4210855e-14, 0.27238852, 0.3056773, 0.8027948, 1.5988436]]
# Epoch: 0 Batch: 25, [Discriminator_A :: Loss: 3.60214462424846e-11], [ Generator :: Loss: [6.676423, 0.2598029, 2.551701e-08, 0.23873925, 0.14463674, 0.8217571, 1.7611035]]
# Epoch: 0 Batch: 25, [Discriminator_B :: Loss: 6.2590732596845555e-09], [ Generator :: Loss: [6.676423, 0.2598029, 2.551701e-08, 0.23873925, 0.14463674, 0.8217571, 1.7611035]]
# Epoch: 0 Batch: 26, [Discriminator_A :: Loss: 3.1059161170839493e-19], [ Generator :: Loss: [6.772605, 0.0, 0.0, 0.2256768, 0.24045205, 0.61299384, 1.4983232]]
# Epoch: 0 Batch: 26, [Discriminator_B :: Loss: 1.1486149004606256e-21], [ Generator :: Loss: [6.772605, 0.0, 0.0, 0.2256768, 0.24045205, 0.61299384, 1.4983232]]
# Epoch: 0 Batch: 27, [Discriminator_A :: Loss: 0.05712825432419777], [ Generator :: Loss: [6.407698, 0.0, 1.4210855e-14, 0.18897781, 0.24404429, 0.54951745, 1.5279593]]
# Epoch: 0 Batch: 27, [Discriminator_B :: Loss: 6.670436562312683e-21], [ Generator :: Loss: [6.407698, 0.0, 1.4210855e-14, 0.18897781, 0.24404429, 0.54951745, 1.5279593]]
# Epoch: 0 Batch: 28, [Discriminator_A :: Loss: 5.2850238060817406e-23], [ Generator :: Loss: [3.9772196, 0.0, 0.0, 0.076514624, 0.101435766, 0.44311625, 1.7545993]]
# Epoch: 0 Batch: 28, [Discriminator_B :: Loss: 1.1629658580484062e-21], [ Generator :: Loss: [3.9772196, 0.0, 0.0, 0.076514624, 0.101435766, 0.44311625, 1.7545993]]
# Epoch: 0 Batch: 29, [Discriminator_A :: Loss: 9.691989257756043e-23], [ Generator :: Loss: [3.7383995, 0.0, 0.0, 0.054915313, 0.09985304, 0.42307016, 1.7676458]]
# Epoch: 0 Batch: 29, [Discriminator_B :: Loss: 1.0163629629237237e-22], [ Generator :: Loss: [3.7383995, 0.0, 0.0, 0.054915313, 0.09985304, 0.42307016, 1.7676458]]
# Epoch: 0 Batch: 30, [Discriminator_A :: Loss: 7.137297926077626e-23], [ Generator :: Loss: [5.119073, 0.0, 0.0, 0.121012144, 0.17777061, 0.53328985, 1.5979552]]
# Epoch: 0 Batch: 30, [Discriminator_B :: Loss: 5.32294056326337e-23], [ Generator :: Loss: [5.119073, 0.0, 0.0, 0.121012144, 0.17777061, 0.53328985, 1.5979552]]
# Epoch: 0 Batch: 31, [Discriminator_A :: Loss: 2.2144586182548665e-05], [ Generator :: Loss: [4.6988955, 0.000603286, 0.0, 0.10015477, 0.15647563, 0.5018606, 1.6301272]]
# Epoch: 0 Batch: 31, [Discriminator_B :: Loss: 1.5839533185552038e-25], [ Generator :: Loss: [4.6988955, 0.000603286, 0.0, 0.10015477, 0.15647563, 0.5018606, 1.6301272]]
# Epoch: 0 Batch: 32, [Discriminator_A :: Loss: 5.843454568826975e-15], [ Generator :: Loss: [4.3903465, 0.0, 0.0, 0.10429733, 0.12704042, 0.4467339, 1.6302353]]
# Epoch: 0 Batch: 32, [Discriminator_B :: Loss: 4.5891997952374335e-25], [ Generator :: Loss: [4.3903465, 0.0, 0.0, 0.10429733, 0.12704042, 0.4467339, 1.6302353]]
# Epoch: 0 Batch: 33, [Discriminator_A :: Loss: 1.541521910120025e-09], [ Generator :: Loss: [6.9475584, 4.9349072e-08, 0.21746689, 0.23422971, 0.25320843, 0.43137354, 1.4243367]]
# Epoch: 0 Batch: 33, [Discriminator_B :: Loss: 1.044666622744135e-19], [ Generator :: Loss: [6.9475584, 4.9349072e-08, 0.21746689, 0.23422971, 0.25320843, 0.43137354, 1.4243367]]
# Epoch: 0 Batch: 34, [Discriminator_A :: Loss: 1.610389156824808e-25], [ Generator :: Loss: [5.034025, 0.0, 0.0, 0.12234941, 0.19882184, 0.40232027, 1.4199926]]
# Epoch: 0 Batch: 34, [Discriminator_B :: Loss: 1.195841687837281e-31], [ Generator :: Loss: [5.034025, 0.0, 0.0, 0.12234941, 0.19882184, 0.40232027, 1.4199926]]
# Epoch: 0 Batch: 35, [Discriminator_A :: Loss: 2.0131228115007222e-29], [ Generator :: Loss: [4.493572, 0.0, 0.0, 0.11776169, 0.14253575, 0.2936797, 1.5969179]]
# Epoch: 0 Batch: 35, [Discriminator_B :: Loss: 3.3682789630368193e-12], [ Generator :: Loss: [4.493572, 0.0, 0.0, 0.11776169, 0.14253575, 0.2936797, 1.5969179]]
# Epoch: 0 Batch: 36, [Discriminator_A :: Loss: 3.5904904049921527e-10], [ Generator :: Loss: [4.5809946, 1.4210855e-14, 3.283276e-10, 0.06742115, 0.2465338, 0.23399843, 1.2074466]]
# Epoch: 0 Batch: 36, [Discriminator_B :: Loss: 1.960932422662154e-05], [ Generator :: Loss: [4.5809946, 1.4210855e-14, 3.283276e-10, 0.06742115, 0.2465338, 0.23399843, 1.2074466]]
# Epoch: 0 Batch: 37, [Discriminator_A :: Loss: 3.8391898963825306e-33], [ Generator :: Loss: [4.826046, 0.0, 0.0, 0.15839043, 0.15161145, 0.3247769, 1.4012502]]
# Epoch: 0 Batch: 37, [Discriminator_B :: Loss: 2.8576740973562664e-09], [ Generator :: Loss: [4.826046, 0.0, 0.0, 0.15839043, 0.15161145, 0.3247769, 1.4012502]]
# Epoch: 0 Batch: 38, [Discriminator_A :: Loss: 3.1389827626071565e-08], [ Generator :: Loss: [5.9386654, 0.0, 0.0001200964, 0.14940834, 0.3035042, 0.2519971, 1.1574233]]
# Epoch: 0 Batch: 38, [Discriminator_B :: Loss: 1.599105917127197e-11], [ Generator :: Loss: [5.9386654, 0.0, 0.0001200964, 0.14940834, 0.3035042, 0.2519971, 1.1574233]]
# Epoch: 0 Batch: 39, [Discriminator_A :: Loss: 0.0915411040186882], [ Generator :: Loss: [5.06271, 0.0, 0.0, 0.09555105, 0.2849338, 0.19309998, 1.0647613]]
# Epoch: 0 Batch: 39, [Discriminator_B :: Loss: 4.865339630743398e-14], [ Generator :: Loss: [5.06271, 0.0, 0.0, 0.09555105, 0.2849338, 0.19309998, 1.0647613]]
# Epoch: 0 Batch: 40, [Discriminator_A :: Loss: 0.1349494606256485], [ Generator :: Loss: [6.1298347, 0.0, 1.4210855e-14, 0.15750375, 0.31593156, 0.2986884, 1.096793]]
# Epoch: 0 Batch: 40, [Discriminator_B :: Loss: 7.4170999068068e-15], [ Generator :: Loss: [6.1298347, 0.0, 1.4210855e-14, 0.15750375, 0.31593156, 0.2986884, 1.096793]]
# Epoch: 0 Batch: 41, [Discriminator_A :: Loss: 1.5818772680642468e-10], [ Generator :: Loss: [6.0006003, 1.7383229e-08, 9.884445e-09, 0.18765262, 0.2601832, 0.44899607, 1.073246]]
# Epoch: 0 Batch: 41, [Discriminator_B :: Loss: 1.3675261695043495e-20], [ Generator :: Loss: [6.0006003, 1.7383229e-08, 9.884445e-09, 0.18765262, 0.2601832, 0.44899607, 1.073246]]
# Epoch: 0 Batch: 42, [Discriminator_A :: Loss: 4.590074022712891e-18], [ Generator :: Loss: [4.799451, 0.0, 3.1974423e-12, 0.12288054, 0.22911873, 0.24830204, 1.0311562]]
# Epoch: 0 Batch: 42, [Discriminator_B :: Loss: 4.543264424726414e-26], [ Generator :: Loss: [4.799451, 0.0, 3.1974423e-12, 0.12288054, 0.22911873, 0.24830204, 1.0311562]]
# Epoch: 0 Batch: 43, [Discriminator_A :: Loss: 4.939554005806212e-19], [ Generator :: Loss: [4.611584, 0.0, 5.684342e-14, 0.11248641, 0.21991247, 0.21286511, 1.0747303]]
# Epoch: 0 Batch: 43, [Discriminator_B :: Loss: 5.46711910091131e-15], [ Generator :: Loss: [4.611584, 0.0, 5.684342e-14, 0.11248641, 0.21991247, 0.21286511, 1.0747303]]
# Epoch: 0 Batch: 44, [Discriminator_A :: Loss: 2.5954946912087856e-20], [ Generator :: Loss: [3.010498, 0.0, 0.0, 0.05034736, 0.10605097, 0.17560461, 1.2709103]]
# Epoch: 0 Batch: 44, [Discriminator_B :: Loss: 2.7407585018888315e-22], [ Generator :: Loss: [3.010498, 0.0, 0.0, 0.05034736, 0.10605097, 0.17560461, 1.2709103]]
# Epoch: 0 Batch: 45, [Discriminator_A :: Loss: 8.262261985692021e-10], [ Generator :: Loss: [5.309573, 1.2906426e-06, 1.4210855e-14, 0.1632804, 0.20646524, 0.39060247, 1.221513]]
# Epoch: 0 Batch: 45, [Discriminator_B :: Loss: 0.040854085236787796], [ Generator :: Loss: [5.309573, 1.2906426e-06, 1.4210855e-14, 0.1632804, 0.20646524, 0.39060247, 1.221513]]
# Epoch: 0 Batch: 46, [Discriminator_A :: Loss: 5.997484922037033e-19], [ Generator :: Loss: [2.6663046, 0.0, 3.637979e-12, 0.036911666, 0.07529856, 0.108449616, 1.4357526]]
# Epoch: 0 Batch: 46, [Discriminator_B :: Loss: 3.778598731108383e-14], [ Generator :: Loss: [2.6663046, 0.0, 3.637979e-12, 0.036911666, 0.07529856, 0.108449616, 1.4357526]]
# Epoch: 0 Batch: 47, [Discriminator_A :: Loss: 4.8060221102748064e-20], [ Generator :: Loss: [3.268345, 0.0, 0.0, 0.107001364, 0.10161609, 0.16909933, 1.0130713]]
# Epoch: 0 Batch: 47, [Discriminator_B :: Loss: 2.1183106859386484e-25], [ Generator :: Loss: [3.268345, 0.0, 0.0, 0.107001364, 0.10161609, 0.16909933, 1.0130713]]
# Epoch: 0 Batch: 48, [Discriminator_A :: Loss: 5.461085178166302e-19], [ Generator :: Loss: [3.8790681, 0.0, 0.0, 0.14809382, 0.11640728, 0.24811056, 0.98594666]]
# Epoch: 0 Batch: 48, [Discriminator_B :: Loss: 8.905345085671366e-30], [ Generator :: Loss: [3.8790681, 0.0, 0.0, 0.14809382, 0.11640728, 0.24811056, 0.98594666]]
# Epoch: 0 Batch: 49, [Discriminator_A :: Loss: 2.93929744941482e-20], [ Generator :: Loss: [4.365573, 0.0, 0.0, 0.17979686, 0.12844098, 0.2805889, 1.0026057]]
# Epoch: 0 Batch: 49, [Discriminator_B :: Loss: 5.360971889395158e-28], [ Generator :: Loss: [4.365573, 0.0, 0.0, 0.17979686, 0.12844098, 0.2805889, 1.0026057]]
# Epoch: 0 Batch: 50, [Discriminator_A :: Loss: 1.8322443478840526e-19], [ Generator :: Loss: [4.098836, 0.0, 0.0, 0.09527488, 0.19958085, 0.17262286, 0.9776555]]
# Epoch: 0 Batch: 50, [Discriminator_B :: Loss: 1.2874273679358354e-30], [ Generator :: Loss: [4.098836, 0.0, 0.0, 0.09527488, 0.19958085, 0.17262286, 0.9776555]]
# Epoch: 0 Batch: 51, [Discriminator_A :: Loss: 4.62505094132439e-18], [ Generator :: Loss: [6.856312, 0.9997473, 0.0, 0.15118542, 0.27838773, 0.30130666, 1.2595263]]
# Epoch: 0 Batch: 51, [Discriminator_B :: Loss: 1.5410197097278177e-22], [ Generator :: Loss: [6.856312, 0.9997473, 0.0, 0.15118542, 0.27838773, 0.30130666, 1.2595263]]
# Epoch: 0 Batch: 52, [Discriminator_A :: Loss: 1.8383842252276981e-19], [ Generator :: Loss: [3.4988964, 0.0, 5.1159077e-13, 0.025938328, 0.184948, 0.06989036, 1.320143]]
# Epoch: 0 Batch: 52, [Discriminator_B :: Loss: 3.605571922840958e-15], [ Generator :: Loss: [3.4988964, 0.0, 5.1159077e-13, 0.025938328, 0.184948, 0.06989036, 1.320143]]
# Epoch: 0 Batch: 53, [Discriminator_A :: Loss: 8.680042505292041e-19], [ Generator :: Loss: [5.077553, 9.094947e-13, 0.0, 0.18395211, 0.16679722, 0.21112052, 1.3589389]]
# Epoch: 0 Batch: 53, [Discriminator_B :: Loss: 2.249368693317684e-28], [ Generator :: Loss: [5.077553, 9.094947e-13, 0.0, 0.18395211, 0.16679722, 0.21112052, 1.3589389]]
# Epoch: 0 Batch: 54, [Discriminator_A :: Loss: 8.913144069861016e-19], [ Generator :: Loss: [5.3098106, 0.0, 0.0, 0.16766581, 0.24262054, 0.22441334, 0.98253417]]
# Epoch: 0 Batch: 54, [Discriminator_B :: Loss: 2.4254703658614104e-18], [ Generator :: Loss: [5.3098106, 0.0, 0.0, 0.16766581, 0.24262054, 0.22441334, 0.98253417]]
# Epoch: 0 Batch: 55, [Discriminator_A :: Loss: 9.987725206883624e-07], [ Generator :: Loss: [6.620943, 1.4154068e-08, 0.0, 0.2803567, 0.24183668, 0.40107417, 0.9979353]]
# Epoch: 0 Batch: 55, [Discriminator_B :: Loss: 0.24297365546226501], [ Generator :: Loss: [6.620943, 1.4154068e-08, 0.0, 0.2803567, 0.24183668, 0.40107417, 0.9979353]]
# Epoch: 0 Batch: 56, [Discriminator_A :: Loss: 9.402742968649262e-19], [ Generator :: Loss: [5.9571614, 1.0, 1.0, 0.1162768, 0.16200814, 0.15991482, 1.014397]]
# Epoch: 0 Batch: 56, [Discriminator_B :: Loss: 1.4173230644676238e-10], [ Generator :: Loss: [5.9571614, 1.0, 1.0, 0.1162768, 0.16200814, 0.15991482, 1.014397]]
# Epoch: 0 Batch: 57, [Discriminator_A :: Loss: 9.556167523936802e-20], [ Generator :: Loss: [4.887038, 0.0, 0.0, 0.1728251, 0.1933198, 0.23137546, 0.9942137]]
# Epoch: 0 Batch: 57, [Discriminator_B :: Loss: 0.4090711176395416], [ Generator :: Loss: [4.887038, 0.0, 0.0, 0.1728251, 0.1933198, 0.23137546, 0.9942137]]
# Epoch: 0 Batch: 58, [Discriminator_A :: Loss: 3.797760029406557e-20], [ Generator :: Loss: [5.1902018, 0.0, 0.0, 0.2015593, 0.18694045, 0.28662533, 1.0185792]]
# Epoch: 0 Batch: 58, [Discriminator_B :: Loss: 4.85985582253731e-35], [ Generator :: Loss: [5.1902018, 0.0, 0.0, 0.2015593, 0.18694045, 0.28662533, 1.0185792]]
# Epoch: 0 Batch: 59, [Discriminator_A :: Loss: 1.7763606341078542e-13], [ Generator :: Loss: [5.8628, 0.0, 0.0, 0.24947676, 0.18932317, 0.28322953, 1.1915712]]
# Epoch: 0 Batch: 59, [Discriminator_B :: Loss: 2.5680749059826815e-21], [ Generator :: Loss: [5.8628, 0.0, 0.0, 0.24947676, 0.18932317, 0.28322953, 1.1915712]]
# Epoch: 0 Batch: 60, [Discriminator_A :: Loss: 2.1559414214768255e-18], [ Generator :: Loss: [6.019142, 0.0, 0.0, 0.27342334, 0.18470725, 0.4526298, 0.9852067]]
# Epoch: 0 Batch: 60, [Discriminator_B :: Loss: 6.246265649678562e-23], [ Generator :: Loss: [6.019142, 0.0, 0.0, 0.27342334, 0.18470725, 0.4526298, 0.9852067]]
# Epoch: 0 Batch: 61, [Discriminator_A :: Loss: 2.5796938483737065e-18], [ Generator :: Loss: [5.192608, 0.0, 0.0, 0.1879016, 0.2008737, 0.38428077, 0.9205741]]
# Epoch: 0 Batch: 61, [Discriminator_B :: Loss: 4.270610749008379e-17], [ Generator :: Loss: [5.192608, 0.0, 0.0, 0.1879016, 0.2008737, 0.38428077, 0.9205741]]
# Epoch: 0 Batch: 62, [Discriminator_A :: Loss: 0.9992735385894775], [ Generator :: Loss: [7.2455263, 0.0024323785, 0.98286146, 0.24098063, 0.24400294, 0.6718142, 0.7385824]]
# Epoch: 0 Batch: 62, [Discriminator_B :: Loss: 0.9999999403953552], [ Generator :: Loss: [7.2455263, 0.0024323785, 0.98286146, 0.24098063, 0.24400294, 0.6718142, 0.7385824]]
# Epoch: 0 Batch: 63, [Discriminator_A :: Loss: 4.049163869757062e-19], [ Generator :: Loss: [2.9436224, 0.0, 0.0, 0.080394655, 0.13783985, 0.1567953, 0.604482]]
# Epoch: 0 Batch: 63, [Discriminator_B :: Loss: 0.00035008095437660813], [ Generator :: Loss: [2.9436224, 0.0, 0.0, 0.080394655, 0.13783985, 0.1567953, 0.604482]]
# Epoch: 0 Batch: 64, [Discriminator_A :: Loss: 2.387585018581717e-09], [ Generator :: Loss: [6.9396286, 0.0, 0.0, 0.25408417, 0.26071042, 0.90198153, 0.8897012]]
# Epoch: 0 Batch: 64, [Discriminator_B :: Loss: 0.001963156508281827], [ Generator :: Loss: [6.9396286, 0.0, 0.0, 0.25408417, 0.26071042, 0.90198153, 0.8897012]]
# Epoch: 0 Batch: 65, [Discriminator_A :: Loss: 2.0786694656757836e-19], [ Generator :: Loss: [2.5175598, 0.0, 0.0, 0.06647798, 0.121786445, 0.1295907, 0.5053248]]
# Epoch: 0 Batch: 65, [Discriminator_B :: Loss: 0.0014348087133839726], [ Generator :: Loss: [2.5175598, 0.0, 0.0, 0.06647798, 0.121786445, 0.1295907, 0.5053248]]
# Epoch: 0 Batch: 66, [Discriminator_A :: Loss: 0.9999980330467224], [ Generator :: Loss: [8.043867, 0.0, 5.684342e-14, 0.26642868, 0.37491122, 0.8661289, 0.76433897]]
# Epoch: 0 Batch: 66, [Discriminator_B :: Loss: 0.9990291595458984], [ Generator :: Loss: [8.043867, 0.0, 5.684342e-14, 0.26642868, 0.37491122, 0.8661289, 0.76433897]]
# Epoch: 0 Batch: 67, [Discriminator_A :: Loss: 2.5329657951851265e-18], [ Generator :: Loss: [8.528582, 1.0, 1.0, 0.38525915, 0.16825753, 0.47914857, 0.51426554]]
# Epoch: 0 Batch: 67, [Discriminator_B :: Loss: 3.450806616456248e-06], [ Generator :: Loss: [8.528582, 1.0, 1.0, 0.38525915, 0.16825753, 0.47914857, 0.51426554]]
# Epoch: 0 Batch: 68, [Discriminator_A :: Loss: 8.112623133021403e-21], [ Generator :: Loss: [5.859247, 0.0, 0.0, 0.3261196, 0.14332315, 0.5416509, 0.62316895]]
# Epoch: 0 Batch: 68, [Discriminator_B :: Loss: 0.03012271039187908], [ Generator :: Loss: [5.859247, 0.0, 0.0, 0.3261196, 0.14332315, 0.5416509, 0.62316895]]
# Epoch: 0 Batch: 69, [Discriminator_A :: Loss: 1.4217805258290478e-19], [ Generator :: Loss: [3.5118163, 0.0, 0.0, 0.10831456, 0.17079955, 0.17192076, 0.54875445]]
# Epoch: 0 Batch: 69, [Discriminator_B :: Loss: 4.4566167613156017e-32], [ Generator :: Loss: [3.5118163, 0.0, 0.0, 0.10831456, 0.17079955, 0.17192076, 0.54875445]]
# Epoch: 0 Batch: 70, [Discriminator_A :: Loss: 3.7791253738433386e-16], [ Generator :: Loss: [5.2832756, 0.0, 0.0, 0.24909624, 0.19172582, 0.3931446, 0.4819104]]
# Epoch: 0 Batch: 70, [Discriminator_B :: Loss: 5.94634241271441e-19], [ Generator :: Loss: [5.2832756, 0.0, 0.0, 0.24909624, 0.19172582, 0.3931446, 0.4819104]]
# Epoch: 0 Batch: 71, [Discriminator_A :: Loss: 1.1437453471634563e-19], [ Generator :: Loss: [7.7591114, 0.0, 0.0, 0.12398814, 0.6103275, 0.1640346, 0.25192058]]
# Epoch: 0 Batch: 71, [Discriminator_B :: Loss: 4.820459887012344e-33], [ Generator :: Loss: [7.7591114, 0.0, 0.0, 0.12398814, 0.6103275, 0.1640346, 0.25192058]]
# Epoch: 0 Batch: 72, [Discriminator_A :: Loss: 2.5156312431721004e-19], [ Generator :: Loss: [2.553745, 0.0, 0.0, 0.08766911, 0.13623138, 0.13816616, 0.1765739]]
# Epoch: 0 Batch: 72, [Discriminator_B :: Loss: 6.401429814830925e-14], [ Generator :: Loss: [2.553745, 0.0, 0.0, 0.08766911, 0.13623138, 0.13816616, 0.1765739]]
# Epoch: 0 Batch: 73, [Discriminator_A :: Loss: 4.597965471475618e-06], [ Generator :: Loss: [6.078699, 0.0, 0.0, 0.14861445, 0.333135, 0.7907179, 0.47048688]]
# Epoch: 0 Batch: 73, [Discriminator_B :: Loss: 0.4997999370098114], [ Generator :: Loss: [6.078699, 0.0, 0.0, 0.14861445, 0.333135, 0.7907179, 0.47048688]]
# Epoch: 0 Batch: 74, [Discriminator_A :: Loss: 2.572423509815794e-17], [ Generator :: Loss: [5.2690425, 0.0, 0.0, 0.34432977, 0.12274145, 0.25287163, 0.34545872]]
# Epoch: 0 Batch: 74, [Discriminator_B :: Loss: 7.040637222648827e-19], [ Generator :: Loss: [5.2690425, 0.0, 0.0, 0.34432977, 0.12274145, 0.25287163, 0.34545872]]
# Epoch: 0 Batch: 75, [Discriminator_A :: Loss: 0.9922377467155457], [ Generator :: Loss: [5.9557652, 0.0, 5.684342e-14, 0.17956865, 0.2738679, 1.1027838, 0.31861573]]
# Epoch: 0 Batch: 75, [Discriminator_B :: Loss: 0.020436633378267288], [ Generator :: Loss: [5.9557652, 0.0, 5.684342e-14, 0.17956865, 0.2738679, 1.1027838, 0.31861573]]
# Epoch: 0 Batch: 76, [Discriminator_A :: Loss: 6.081860647100257e-06], [ Generator :: Loss: [6.6387725, 0.0, 3.1127456e-10, 0.36386204, 0.21399018, 0.5908996, 0.26935068]]
# Epoch: 0 Batch: 76, [Discriminator_B :: Loss: 6.639119322181331e-26], [ Generator :: Loss: [6.6387725, 0.0, 3.1127456e-10, 0.36386204, 0.21399018, 0.5908996, 0.26935068]]
# Epoch: 0 Batch: 77, [Discriminator_A :: Loss: 1.3842018656971286e-18], [ Generator :: Loss: [6.152302, 1.0, 1.0, 0.18107815, 0.14555386, 0.67279863, 0.21318284]]
# Epoch: 0 Batch: 77, [Discriminator_B :: Loss: 4.489621035145912e-23], [ Generator :: Loss: [6.152302, 1.0, 1.0, 0.18107815, 0.14555386, 0.67279863, 0.21318284]]
# Epoch: 0 Batch: 78, [Discriminator_A :: Loss: 6.536086949449071e-11], [ Generator :: Loss: [7.3260193, 0.0, 0.0, 0.25612825, 0.32490805, 0.994627, 0.52102923]]
# Epoch: 0 Batch: 78, [Discriminator_B :: Loss: 1.4387610652194165e-17], [ Generator :: Loss: [7.3260193, 0.0, 0.0, 0.25612825, 0.32490805, 0.994627, 0.52102923]]
# Epoch: 0 Batch: 79, [Discriminator_A :: Loss: 1.9136639366479358e-06], [ Generator :: Loss: [5.4704313, 0.0, 1.4210855e-14, 0.2679499, 0.17456031, 0.654197, 0.3911322]]
# Epoch: 0 Batch: 79, [Discriminator_B :: Loss: 1.7307887845980455e-18], [ Generator :: Loss: [5.4704313, 0.0, 1.4210855e-14, 0.2679499, 0.17456031, 0.654197, 0.3911322]]
# Epoch: 0 Batch: 80, [Discriminator_A :: Loss: 0.02141263522207737], [ Generator :: Loss: [5.2949805, 1.09299805e-08, 0.0, 0.16848335, 0.26237547, 0.4113612, 0.5750314]]
# Epoch: 0 Batch: 80, [Discriminator_B :: Loss: 0.49988293647766113], [ Generator :: Loss: [5.2949805, 1.09299805e-08, 0.0, 0.16848335, 0.26237547, 0.4113612, 0.5750314]]
# Epoch: 0 Batch: 81, [Discriminator_A :: Loss: 3.755697766011265e-17], [ Generator :: Loss: [2.6582823, 0.0, 0.0, 0.09316678, 0.09481114, 0.43628204, 0.34222102]]
# Epoch: 0 Batch: 81, [Discriminator_B :: Loss: 3.524439620188417e-24], [ Generator :: Loss: [2.6582823, 0.0, 0.0, 0.09316678, 0.09481114, 0.43628204, 0.34222102]]
# Epoch: 0 Batch: 82, [Discriminator_A :: Loss: 2.4341215451399983e-15], [ Generator :: Loss: [3.2017438, 0.0, 0.0, 0.13449411, 0.11587497, 0.44274458, 0.25530857]]
# Epoch: 0 Batch: 82, [Discriminator_B :: Loss: 2.9003088464108834e-24], [ Generator :: Loss: [3.2017438, 0.0, 0.0, 0.13449411, 0.11587497, 0.44274458, 0.25530857]]
# Epoch: 0 Batch: 83, [Discriminator_A :: Loss: 4.896056650383063e-12], [ Generator :: Loss: [3.2539997, 0.0, 0.0, 0.14362608, 0.105020165, 0.50473166, 0.26280537]]
# Epoch: 0 Batch: 83, [Discriminator_B :: Loss: 1.931809600815165e-23], [ Generator :: Loss: [3.2539997, 0.0, 0.0, 0.14362608, 0.105020165, 0.50473166, 0.26280537]]
# Epoch: 0 Batch: 84, [Discriminator_A :: Loss: 9.947145684918723e-08], [ Generator :: Loss: [7.728458, 0.0, 0.0, 0.28639096, 0.4118938, 0.2947639, 0.45084614]]
# Epoch: 0 Batch: 84, [Discriminator_B :: Loss: 2.8982743714721143e-16], [ Generator :: Loss: [7.728458, 0.0, 0.0, 0.28639096, 0.4118938, 0.2947639, 0.45084614]]
# Epoch: 0 Batch: 85, [Discriminator_A :: Loss: 1.2390309444110362e-18], [ Generator :: Loss: [4.017865, 0.0, 0.0, 0.19107339, 0.15360142, 0.29848236, 0.27263454]]
# Epoch: 0 Batch: 85, [Discriminator_B :: Loss: 4.938823441469452e-25], [ Generator :: Loss: [4.017865, 0.0, 0.0, 0.19107339, 0.15360142, 0.29848236, 0.27263454]]
# Epoch: 0 Batch: 86, [Discriminator_A :: Loss: 1.2415617810433246e-19], [ Generator :: Loss: [6.3526998, 1.0, 1.0, 0.13338831, 0.25669986, 0.18437529, 0.26744252]]
# Epoch: 0 Batch: 86, [Discriminator_B :: Loss: 0.49904027581214905], [ Generator :: Loss: [6.3526998, 1.0, 1.0, 0.13338831, 0.25669986, 0.18437529, 0.26744252]]
# Epoch: 0 Batch: 87, [Discriminator_A :: Loss: 4.646202363177677e-17], [ Generator :: Loss: [7.8442526, 1.0, 1.0, 0.2532118, 0.246855, 0.40591675, 0.4376684]]
# Epoch: 0 Batch: 87, [Discriminator_B :: Loss: 1.5885456144948407e-11], [ Generator :: Loss: [7.8442526, 1.0, 1.0, 0.2532118, 0.246855, 0.40591675, 0.4376684]]
# Epoch: 0 Batch: 88, [Discriminator_A :: Loss: 5.922909936924432e-19], [ Generator :: Loss: [7.820182, 1.7081703e-16, 1.0, 0.11670084, 0.52699506, 0.15090299, 0.23232004]]
# Epoch: 0 Batch: 88, [Discriminator_B :: Loss: 0.49999916553497314], [ Generator :: Loss: [7.820182, 1.7081703e-16, 1.0, 0.11670084, 0.52699506, 0.15090299, 0.23232004]]
# Epoch: 0 Batch: 89, [Discriminator_A :: Loss: 0.0005282873171381652], [ Generator :: Loss: [9.793333, 0.36228746, 0.0002490602, 0.44912142, 0.38670814, 0.6322626, 0.44023862]]
# Epoch: 0 Batch: 89, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [9.793333, 0.36228746, 0.0002490602, 0.44912142, 0.38670814, 0.6322626, 0.44023862]]
# Epoch: 0 Batch: 90, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [7.821586, 0.0, 0.0, 0.48567498, 0.23245254, 0.31741327, 0.32289803]]
# Epoch: 0 Batch: 90, [Discriminator_B :: Loss: 0.49998152256011963], [ Generator :: Loss: [7.821586, 0.0, 0.0, 0.48567498, 0.23245254, 0.31741327, 0.32289803]]
# Epoch: 0 Batch: 91, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [7.98046, 1.4210855e-14, 1.0, 0.38321474, 0.23248133, 0.37871313, 0.444786]]
# Epoch: 0 Batch: 91, [Discriminator_B :: Loss: 3.278129308002533e-31], [ Generator :: Loss: [7.98046, 1.4210855e-14, 1.0, 0.38321474, 0.23248133, 0.37871313, 0.444786]]
# Epoch: 0 Batch: 92, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [8.464936, 0.0, 0.9999987, 0.40772694, 0.25786638, 0.4188792, 0.39012483]]
# Epoch: 0 Batch: 92, [Discriminator_B :: Loss: 8.552347935619764e-06], [ Generator :: Loss: [8.464936, 0.0, 0.9999987, 0.40772694, 0.25786638, 0.4188792, 0.39012483]]
# Epoch: 0 Batch: 93, [Discriminator_A :: Loss: 0.49999988079071045], [ Generator :: Loss: [9.655524, 0.0, 1.0, 0.46227682, 0.3140061, 0.41840798, 0.4742869]]
# ...
# Epoch: 4 Batch: 345, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.5168667, 0.0, 0.0, 0.10798402, 0.118678145, 0.121028244, 0.12921691]]
# Epoch: 4 Batch: 346, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [3.9588664, 1.0, 1.0, 0.091662414, 0.0821611, 0.11388585, 0.1067455]]
# Epoch: 4 Batch: 346, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [3.9588664, 1.0, 1.0, 0.091662414, 0.0821611, 0.11388585, 0.1067455]]
# Epoch: 4 Batch: 347, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [3.6511817, 1.0, 1.0, 0.0919023, 0.050815217, 0.1352393, 0.08876701]]
# Epoch: 4 Batch: 347, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [3.6511817, 1.0, 1.0, 0.0919023, 0.050815217, 0.1352393, 0.08876701]]
# Epoch: 4 Batch: 348, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [3.7940245, 1.0, 1.0, 0.092172936, 0.064856395, 0.12897038, 0.094760664]]
# Epoch: 4 Batch: 348, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [3.7940245, 1.0, 1.0, 0.092172936, 0.064856395, 0.12897038, 0.094760664]]
# Epoch: 4 Batch: 349, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.5253938, 0.0, 0.0, 0.06898205, 0.06456261, 0.10017126, 0.08977606]]
# Epoch: 4 Batch: 349, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.5253938, 0.0, 0.0, 0.06898205, 0.06456261, 0.10017126, 0.08977606]]
# Epoch: 4 Batch: 350, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.583719, 0.0, 0.0, 0.06659934, 0.07367568, 0.10525151, 0.07571726]]
# Epoch: 4 Batch: 350, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.583719, 0.0, 0.0, 0.06659934, 0.07367568, 0.10525151, 0.07571726]]
# Epoch: 4 Batch: 351, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.5264611, 0.0, 0.0, 0.07242505, 0.061249174, 0.102046356, 0.08767247]]
# Epoch: 4 Batch: 351, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.5264611, 0.0, 0.0, 0.07242505, 0.061249174, 0.102046356, 0.08767247]]
# Epoch: 4 Batch: 352, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.8780465, 1.0, 1.0, 0.039470844, 0.033955567, 0.07311909, 0.07066327]]
# Epoch: 4 Batch: 352, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.8780465, 1.0, 1.0, 0.039470844, 0.033955567, 0.07311909, 0.07066327]]
# Epoch: 4 Batch: 353, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.766658, 0.0, 0.0, 0.080835626, 0.07649734, 0.10000605, 0.09332214]]
# Epoch: 4 Batch: 353, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.766658, 0.0, 0.0, 0.080835626, 0.07649734, 0.10000605, 0.09332214]]
# Epoch: 4 Batch: 354, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.410793, 0.0, 0.0, 0.10799869, 0.10973792, 0.11850713, 0.11491976]]
# Epoch: 4 Batch: 354, [Discriminator_B :: Loss: 0.5000014901161194], [ Generator :: Loss: [2.410793, 0.0, 0.0, 0.10799869, 0.10973792, 0.11850713, 0.11491976]]
# Epoch: 4 Batch: 355, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [3.4981449, 1.0, 1.0, 0.066039935, 0.06692254, 0.071038745, 0.09748115]]
# Epoch: 4 Batch: 355, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [3.4981449, 1.0, 1.0, 0.066039935, 0.06692254, 0.071038745, 0.09748115]]
# Epoch: 4 Batch: 356, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.7862045, 0.0, 0.0, 0.07968412, 0.07849783, 0.106057346, 0.09832757]]
# Epoch: 4 Batch: 356, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.7862045, 0.0, 0.0, 0.07968412, 0.07849783, 0.106057346, 0.09832757]]
# Epoch: 4 Batch: 357, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.6494567, 0.0, 0.0, 0.08506192, 0.060107753, 0.09883657, 0.0989235]]
# Epoch: 4 Batch: 357, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.6494567, 0.0, 0.0, 0.08506192, 0.060107753, 0.09883657, 0.0989235]]
# Epoch: 4 Batch: 358, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.6440942, 0.0, 0.0, 0.068398654, 0.080494165, 0.053612404, 0.10155363]]
# Epoch: 4 Batch: 358, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.6440942, 0.0, 0.0, 0.068398654, 0.080494165, 0.053612404, 0.10155363]]
# Epoch: 4 Batch: 359, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.7912469, 0.0, 0.0, 0.07471876, 0.08432702, 0.09792888, 0.10286019]]
# Epoch: 4 Batch: 359, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.7912469, 0.0, 0.0, 0.07471876, 0.08432702, 0.09792888, 0.10286019]]
# Epoch: 4 Batch: 360, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.455925, 0.0, 0.0, 0.062703624, 0.068391174, 0.06821428, 0.07676284]]
# Epoch: 4 Batch: 360, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.455925, 0.0, 0.0, 0.062703624, 0.068391174, 0.06821428, 0.07676284]]
# Epoch: 4 Batch: 361, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.5237327, 0.0, 0.0, 0.11651539, 0.10899805, 0.13647331, 0.13212496]]
# Epoch: 4 Batch: 361, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.5237327, 0.0, 0.0, 0.11651539, 0.10899805, 0.13647331, 0.13212496]]
# Epoch: 4 Batch: 362, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.2403122, 0.0, 0.0, 0.054533742, 0.05514453, 0.06293018, 0.08059935]]
# Epoch: 4 Batch: 362, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.2403122, 0.0, 0.0, 0.054533742, 0.05514453, 0.06293018, 0.08059935]]
# Epoch: 4 Batch: 363, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.3249369, 0.0, 0.0, 0.05985561, 0.055652693, 0.09685903, 0.07299492]]
# Epoch: 4 Batch: 363, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.3249369, 0.0, 0.0, 0.05985561, 0.055652693, 0.09685903, 0.07299492]]
# Epoch: 4 Batch: 364, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.0596077, 0.0, 0.0, 0.08700358, 0.09803589, 0.10434021, 0.104872905]]
# Epoch: 4 Batch: 364, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.0596077, 0.0, 0.0, 0.08700358, 0.09803589, 0.10434021, 0.104872905]]
# Epoch: 4 Batch: 365, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.473526, 0.0, 0.0, 0.067604594, 0.06159464, 0.095538184, 0.08599546]]
# Epoch: 4 Batch: 365, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.473526, 0.0, 0.0, 0.067604594, 0.06159464, 0.095538184, 0.08599546]]
# Epoch: 4 Batch: 366, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.6898061, 0.0, 0.0, 0.09219767, 0.056451447, 0.12682748, 0.07648741]]
# Epoch: 4 Batch: 366, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.6898061, 0.0, 0.0, 0.09219767, 0.056451447, 0.12682748, 0.07648741]]
# Epoch: 4 Batch: 367, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.3216649, 0.0, 0.0, 0.059024777, 0.05411007, 0.11438209, 0.07593456]]
# Epoch: 4 Batch: 367, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.3216649, 0.0, 0.0, 0.059024777, 0.05411007, 0.11438209, 0.07593456]]
# Epoch: 4 Batch: 368, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.0840114, 0.0, 0.0, 0.036296204, 0.058673687, 0.049597815, 0.08471468]]
# Epoch: 4 Batch: 368, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.0840114, 0.0, 0.0, 0.036296204, 0.058673687, 0.049597815, 0.08471468]]
# Epoch: 4 Batch: 369, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.7572932, 0.0, 0.0, 0.13645422, 0.117485195, 0.13430652, 0.08359273]]
# Epoch: 4 Batch: 369, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.7572932, 0.0, 0.0, 0.13645422, 0.117485195, 0.13430652, 0.08359273]]
# Epoch: 4 Batch: 370, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.827836, 0.0, 0.0, 0.11897911, 0.13858917, 0.13752225, 0.11463129]]
# Epoch: 4 Batch: 370, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.827836, 0.0, 0.0, 0.11897911, 0.13858917, 0.13752225, 0.11463129]]
# Epoch: 4 Batch: 371, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.4581064, 0.0, 0.0, 0.06575388, 0.063873276, 0.09041307, 0.071421705]]
# Epoch: 4 Batch: 371, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.4581064, 0.0, 0.0, 0.06575388, 0.063873276, 0.09041307, 0.071421705]]
# Epoch: 4 Batch: 372, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.9247452, 0.0, 0.0, 0.09105748, 0.07996294, 0.12364936, 0.09089172]]
# Epoch: 4 Batch: 372, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.9247452, 0.0, 0.0, 0.09105748, 0.07996294, 0.12364936, 0.09089172]]
# Epoch: 4 Batch: 373, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.877975, 0.0, 0.0, 0.086888075, 0.079052895, 0.11806552, 0.10049975]]
# Epoch: 4 Batch: 373, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.877975, 0.0, 0.0, 0.086888075, 0.079052895, 0.11806552, 0.10049975]]
# Epoch: 4 Batch: 374, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.6044028, 0.0, 0.0, 0.13188839, 0.098996654, 0.21831952, 0.07723306]]
# Epoch: 4 Batch: 374, [Discriminator_B :: Loss: 1.0], [ Generator :: Loss: [2.6044028, 0.0, 0.0, 0.13188839, 0.098996654, 0.21831952, 0.07723306]]
# Epoch: 4 Batch: 375, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.780741, 0.0, 0.0, 0.06649591, 0.09805785, 0.06276458, 0.07243888]]
# Epoch: 4 Batch: 375, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.780741, 0.0, 0.0, 0.06649591, 0.09805785, 0.06276458, 0.07243888]]
# Epoch: 4 Batch: 376, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.9007609, 0.0, 0.0, 0.081735246, 0.08702001, 0.11099136, 0.10221695]]
# Epoch: 4 Batch: 376, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.9007609, 0.0, 0.0, 0.081735246, 0.08702001, 0.11099136, 0.10221695]]
# Epoch: 4 Batch: 377, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.7893931, 0.0, 0.0, 0.07546851, 0.08231449, 0.10938315, 0.10217986]]
# Epoch: 4 Batch: 377, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.7893931, 0.0, 0.0, 0.07546851, 0.08231449, 0.10938315, 0.10217986]]
# Epoch: 4 Batch: 378, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.8823718, 0.0, 0.0, 0.10302953, 0.06794077, 0.09429777, 0.078371]]
# Epoch: 4 Batch: 378, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.8823718, 0.0, 0.0, 0.10302953, 0.06794077, 0.09429777, 0.078371]]
# Epoch: 4 Batch: 379, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.7166945, 0.0, 0.0, 0.08663325, 0.067289256, 0.09393117, 0.08353816]]
# Epoch: 4 Batch: 379, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.7166945, 0.0, 0.0, 0.08663325, 0.067289256, 0.09393117, 0.08353816]]
# Epoch: 4 Batch: 380, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.8563528, 0.0, 0.0, 0.06961131, 0.10471468, 0.072064325, 0.041028563]]
# Epoch: 4 Batch: 380, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.8563528, 0.0, 0.0, 0.06961131, 0.10471468, 0.072064325, 0.041028563]]
# Epoch: 4 Batch: 381, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.5170195, 0.0, 0.0, 0.13192484, 0.09241854, 0.15295404, 0.12063137]]
# Epoch: 4 Batch: 381, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.5170195, 0.0, 0.0, 0.13192484, 0.09241854, 0.15295404, 0.12063137]]
# Epoch: 4 Batch: 382, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.0614711, 0.0, 0.0, 0.04399605, 0.047289338, 0.08649948, 0.062117644]]
# Epoch: 4 Batch: 382, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.0614711, 0.0, 0.0, 0.04399605, 0.047289338, 0.08649948, 0.062117644]]
# Epoch: 4 Batch: 383, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [0.8023944, 0.0, 0.0, 0.039888326, 0.029380739, 0.040373795, 0.06932999]]
# Epoch: 4 Batch: 383, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [0.8023944, 0.0, 0.0, 0.039888326, 0.029380739, 0.040373795, 0.06932999]]
# Epoch: 4 Batch: 384, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.0901245, 0.0, 0.0, 0.044382997, 0.052421853, 0.06159035, 0.060485546]]
# Epoch: 4 Batch: 384, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.0901245, 0.0, 0.0, 0.044382997, 0.052421853, 0.06159035, 0.060485546]]
# Epoch: 4 Batch: 385, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [0.98283637, 0.0, 0.0, 0.03679764, 0.05006495, 0.057259314, 0.056951158]]
# Epoch: 4 Batch: 385, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [0.98283637, 0.0, 0.0, 0.03679764, 0.05006495, 0.057259314, 0.056951158]]
# Epoch: 4 Batch: 386, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.9594364, 0.0, 0.0, 0.14418504, 0.12166852, 0.18371527, 0.11718555]]
# Epoch: 4 Batch: 386, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.9594364, 0.0, 0.0, 0.14418504, 0.12166852, 0.18371527, 0.11718555]]
# Epoch: 4 Batch: 387, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.5788068, 0.0, 0.0, 0.06810236, 0.07133207, 0.097302526, 0.087159924]]
# Epoch: 4 Batch: 387, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.5788068, 0.0, 0.0, 0.06810236, 0.07133207, 0.097302526, 0.087159924]]
# Epoch: 4 Batch: 388, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.292975, 0.0, 0.0, 0.05557674, 0.057972874, 0.09040497, 0.06707379]]
# Epoch: 4 Batch: 388, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.292975, 0.0, 0.0, 0.05557674, 0.057972874, 0.09040497, 0.06707379]]
# Epoch: 4 Batch: 389, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.4231842, 0.0, 0.0, 0.1335999, 0.07902782, 0.20945641, 0.08745057]]
# Epoch: 4 Batch: 389, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.4231842, 0.0, 0.0, 0.1335999, 0.07902782, 0.20945641, 0.08745057]]
# Epoch: 4 Batch: 390, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.6194429, 0.0, 0.0, 0.070741765, 0.073839046, 0.08525475, 0.08838001]]
# Epoch: 4 Batch: 390, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.6194429, 0.0, 0.0, 0.070741765, 0.073839046, 0.08525475, 0.08838001]]
# Epoch: 4 Batch: 391, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.0356691, 0.0, 0.0, 0.052182376, 0.03834177, 0.06564499, 0.06478265]]
# Epoch: 4 Batch: 391, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.0356691, 0.0, 0.0, 0.052182376, 0.03834177, 0.06564499, 0.06478265]]
# Epoch: 4 Batch: 392, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.2420183, 0.0, 0.0, 0.049608294, 0.059020273, 0.07842876, 0.07730384]]
# Epoch: 4 Batch: 392, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.2420183, 0.0, 0.0, 0.049608294, 0.059020273, 0.07842876, 0.07730384]]
# Epoch: 4 Batch: 393, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.2853415, 0.0, 0.0, 0.05393841, 0.05985514, 0.058879107, 0.088526845]]
# Epoch: 4 Batch: 393, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.2853415, 0.0, 0.0, 0.05393841, 0.05985514, 0.058879107, 0.088526845]]
# Epoch: 4 Batch: 394, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.1736919, 0.0, 0.0, 0.051882338, 0.051191777, 0.068066, 0.074884705]]
# Epoch: 4 Batch: 394, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.1736919, 0.0, 0.0, 0.051882338, 0.051191777, 0.068066, 0.074884705]]
# Epoch: 4 Batch: 395, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.2270819, 0.0, 0.0, 0.050516147, 0.057866767, 0.069536135, 0.07371664]]
# Epoch: 4 Batch: 395, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.2270819, 0.0, 0.0, 0.050516147, 0.057866767, 0.069536135, 0.07371664]]
# Epoch: 4 Batch: 396, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [2.071381, 0.0, 0.0, 0.09741857, 0.08496077, 0.1352699, 0.11231789]]
# Epoch: 4 Batch: 396, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [2.071381, 0.0, 0.0, 0.09741857, 0.08496077, 0.1352699, 0.11231789]]
# Epoch: 4 Batch: 397, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [3.1795862, 1.0, 1.0, 0.04816866, 0.055658504, 0.068578154, 0.07273622]]
# Epoch: 4 Batch: 397, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [3.1795862, 1.0, 1.0, 0.04816866, 0.055658504, 0.068578154, 0.07273622]]
# Epoch: 4 Batch: 398, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [1.6698571, 0.0, 0.0, 0.07974574, 0.0671301, 0.10699369, 0.09410517]]
# Epoch: 4 Batch: 398, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [1.6698571, 0.0, 0.0, 0.07974574, 0.0671301, 0.10699369, 0.09410517]]
# Epoch: 4 Batch: 399, [Discriminator_A :: Loss: 0.5], [ Generator :: Loss: [0.8964757, 0.0, 0.0, 0.04498348, 0.034427628, 0.05438585, 0.047978774]]
# Epoch: 4 Batch: 399, [Discriminator_B :: Loss: 0.5], [ Generator :: Loss: [0.8964757, 0.0, 0.0, 0.04498348, 0.034427628, 0.05438585, 0.047978774]]
